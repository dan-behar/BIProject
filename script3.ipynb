# %% [markdown]
# ## Exploracion de la data del censo

# %%
import pandas as pd
import numpy as np

# %%
states = ['CA', 'TX', 'FL', 'NY', 'PA', 'IL', 'OH', 'GA', 'NC', 'MI', 'NJ', 'VA', 'WA', 'AZ', 'MA', 'TN']

# %%
df_EdadSex = pd.read_excel("DataCensus/EdadSexo.xlsx", sheet_name = "Data")
df_EdadSex.head()
# Out:
#          Unnamed: 0    Arizona       Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0               NaN      Total              NaN    Percent              NaN
# 1             Label   Estimate  Margin of Error   Estimate  Margin of Error
# 2  Total population  7,276,316            *****        (X)              (X)
# 3               AGE        NaN              NaN        NaN              NaN
# 4     Under 5 years    402,255           ±1,323       5.5%             ±0.1
#
#   Unnamed: 5       Unnamed: 6    Unnamed: 7       Unnamed: 8 Unnamed: 9  ...  \
# 0       Male              NaN  Percent Male              NaN     Female  ...
# 1   Estimate  Margin of Error      Estimate  Margin of Error   Estimate  ...
# 2  3,629,620           ±2,852           (X)              (X)  3,646,696  ...
# 3        NaN              NaN           NaN              NaN        NaN  ...
# 4    203,199           ±1,688          5.6%             ±0.1    199,056  ...
#
# ...

# %%
df_EdadSex.columns[0:20]
# Out:
# Index(['Unnamed: 0', 'Arizona', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'California',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')
